# %%
import pandas as pd
import numpy as np
from utils.const import *
from utils.physics import *
import matplotlib.pyplot as plt
from copy import copy
cmap = copy(plt.cm.get_cmap("jet"))
from scipy.optimize import least_squares

# %%
target
# Out:
# [0, 0, 0]

# %%
for cut in [cuts_dvcs_CDFT_Inb_3sigma, cuts_dvcs_CDFT_Inb_2sigma, cuts_dvcs_CDFT_Inb_4sigma]:
    print([cut["MM2_ep_ub"] - cut["MM2_ep_lb"]>0, cut["MM2_eg_ub"] - cut["MM2_eg_lb"]>0, cut["MM2_epg_ub"] - cut["MM2_epg_lb"]>0, cut["ME_epg_ub"] - cut["ME_epg_lb"]>0, cut["coplanarity_ub"]>0, cut["MPt_ub"]>0, cut["reconGam_ub"]>0])
    x = np.linspace(2, 10, 101)
    plt.plot(x, np.poly1d(cut["coneAngle_ub"])(x), color = 'r')
    plt.plot(x, np.poly1d(cut["coneAngle_lb"])(x), color = 'b')
    plt.show()
# Out:
# [True, True, True, True, True, True, True]
# [True, True, True, True, True, True, True]
# [True, True, True, True, True, True, True]

# %%
for cut in [cuts_dvcs_CD_Inb_3sigma, cuts_dvcs_CD_Inb_2sigma, cuts_dvcs_CD_Inb_4sigma]:
    print([cut["MM2_ep_ub"] - cut["MM2_ep_lb"]>0, cut["MM2_eg_ub"] - cut["MM2_eg_lb"]>0, cut["MM2_epg_ub"] - cut["MM2_epg_lb"]>0, cut["ME_epg_ub"] - cut["ME_epg_lb"]>0, cut["coplanarity_ub"]>0, cut["MPt_ub"]>0, cut["reconGam_ub"]>0])
    x = np.linspace(2, 10, 101)
    plt.plot(x, np.poly1d(cut["coneAngle_ub"])(x), color = 'r')
    plt.plot(x, np.poly1d(cut["coneAngle_lb"])(x), color = 'b')
    plt.show()
# Out:
# [True, True, True, True, True, True, True]
# [True, True, True, True, True, True, True]
# [True, True, True, True, True, True, True]

# %%
for cut in [cuts_dvcs_FD_Inb_3sigma, cuts_dvcs_FD_Inb_2sigma, cuts_dvcs_FD_Inb_4sigma]:
    print([cut["MM2_ep_ub"] - cut["MM2_ep_lb"]>0, cut["MM2_eg_ub"] - cut["MM2_eg_lb"]>0, cut["MM2_epg_ub"] - cut["MM2_epg_lb"]>0, cut["ME_epg_ub"] - cut["ME_epg_lb"]>0, cut["coplanarity_ub"]>0, cut["MPt_ub"]>0, cut["reconGam_ub"]>0])
    x = np.linspace(2, 10, 101)
    plt.plot(x, np.poly1d(cut["coneAngle_ub"])(x), color = 'r')
    plt.plot(x, np.poly1d(cut["coneAngle_lb"])(x), color = 'b')
    plt.show()
# Out:
# [True, True, True, True, True, True, True]
# [True, True, True, True, True, True, True]
# [True, True, True, True, True, True, True]
