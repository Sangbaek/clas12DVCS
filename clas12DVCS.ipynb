# %% [markdown]
# # clas12 DVCS analysis

# %% [markdown]
# ## 1. Load Data

# %% [markdown]
# To effectively use the dataset, we use hashmap for data set and simulations of DVCS and DVpi0. It takes a while, so don't forget reading this whenever the machine is rebooted, or this page is reloaded.

# %%
from utils.epg import *

# %%
#DVCS from experiment, inbending
fname = "~/Dropbox (MIT)/data/data/dvcs_inb.root"
epg = epgFromROOT(fname)
dvpi0 = epg.getDVpi0()
dvcs = epg.getDVCS(sub2g=True)
dvcsExpInb = {"fname":fname, "epg": epg, "dvpi0": dvpi0, "dvcs": dvcs, "df_epg": epg.df_epg, "df_epgg": epg.df_epgg}

# %%
#DVCS from experiment, outbending
fname = "~/Dropbox (MIT)/data/data/dvcs_outb.root"
epg = epgFromROOT(fname)
dvpi0 = epg.getDVpi0()
dvcs = epg.getDVCS(sub2g=True)
dvcsExpOutb = {"fname":fname, "epg": epg, "dvpi0": dvpi0, "dvcs": dvcs, "df_epg": epg.df_epg, "df_epgg": epg.df_epgg}

# %%
#pi0 from experiment, inbending
fname = "~/Dropbox (MIT)/data/data/pi0_inb.root"
epg = epgFromROOT(fname)
dvpi0 = epg.getDVpi0()
dvcs = epg.getDVCS(sub2g=True)
pi0ExpInb = {"fname":fname, "epg": epg, "dvpi0": dvpi0, "dvcs": dvcs, "df_epg": epg.df_epg, "df_epgg": epg.df_epgg}

# %%
#pi0 from experiment, outbending
fname = "~/Dropbox (MIT)/data/data/pi0_outb.root"
epg = epgFromROOT(fname)
dvpi0 = epg.getDVpi0()
dvcs = epg.getDVCS(sub2g=True)
pi0ExpOutb = {"fname":fname, "epg": epg, "dvpi0": dvpi0, "dvcs": dvcs, "df_epg": epg.df_epg, "df_epgg": epg.df_epgg}

# %%
#dvcs from simulation, vz correct, vxvy (0, -0.05), gen
fname = "~/Dropbox (MIT)/data/MC/nonradVzCorrInbMC.root"
epg = epgFromROOT(fname, mc=True)
# dvpi0 = epg.getDVpi0()
dvcs = epg.getDVCS()
dvcsMCVzCorrInb = {"fname_gen":fname, "epg_gen": epg, "dvcs_gen": dvcs, "df_epg_gen": epg.df_epg}

# %%
#dvcs from simulation, vz correct, vxvy (0, -0.05), rec
fname = "~/Dropbox (MIT)/data/MC/nonradVzCorrInbREC.root"
epg = epgFromROOT(fname, rec=True)
dvpi0 = epg.getDVpi0()
dvcs = epg.getDVCS(sub2g=True)
dvcsMCVzCorrInb.update({"fname":fname, "epg": epg, "dvpi0": dvpi0, "dvcs": dvcs, "df_epg": epg.df_epg, "df_epgg": epg.df_epgg})

# %%
#dvcs from simulation, vz correct, vxvy (0.05, 0.1), gen
fname = "~/Dropbox (MIT)/data/MC/nonradVxyzCorrInbMC.root"
epg = epgFromROOT(fname, mc=True)
# dvpi0 = epg.getDVpi0()
dvcs = epg.getDVCS()
dvcsMCVxyzCorrInb = {"fname_gen":fname, "epg_gen":epg, "dvcs_gen": dvcs, "df_epg_gen": epg.df_epg}

# %%
#dvcs from simulation, vz correct, vxvy (0, -0.05), rec
fname = "~/Dropbox (MIT)/data/MC/nonradVxyzCorrInbREC.root"
epg = epgFromROOT(fname, rec=True)
dvpi0 = epg.getDVpi0()
dvcs = epg.getDVCS(sub2g=True)
dvcsMCVxyzCorrInb.update({"fname":fname, "epg": epg, "dvpi0": dvpi0, "dvcs": dvcs, "df_epg": epg.df_epg, "df_epgg": epg.df_epgg})

# %%
#dvcs from simulation, vz correct, vxvy (0.05, 0.1), gen
fname = "~/Dropbox (MIT)/data/MC/nonradVxyzCorrOutbMC.root"
epg = epgFromROOT(fname, mc=True)
# dvpi0 = epg.getDVpi0()
dvcs = epg.getDVCS()
dvcsMCVxyzCorrOutb = {"fname_gen":fname, "epg_gen": epg,"dvcs_gen": dvcs, "df_epg_gen": epg.df_epg}

# %%
#dvcs from simulation, vz correct, vxvy (0.05, 0.1), REC
fname = "~/Dropbox (MIT)/data/MC/nonradVxyzCorrOutbREC.root"
epg = epgFromROOT(fname, rec=True)
dvpi0 = epg.getDVpi0()
dvcs = epg.getDVCS(sub2g=True)
dvcsMCVxyzCorrOutb.update({"fname":fname, "epg": epg, "dvpi0": dvpi0, "dvcs": dvcs, "df_epg": epg.df_epg, "df_epgg": epg.df_epgg})

# %%
#pi0 from Andrey, inb, rec
fname = "~/Dropbox (MIT)/data/MC/dnp/pi0DNPInbMC.root"
epg = epgFromROOT(fname, mc=True)
dvpi0 = epg.getDVpi0()
dvcs = epg.getDVCS()
pi0MCdnpInb = {"fname_gen":fname, "epg_gen": epg, "dvpi0_gen": dvpi0, "dvcs_gen":dvcs, "df_epg_gen": epg.df_epg, "df_epgg_gen": epg.df_epgg}

# %%
#pi0 from Andrey, inb, rec
fname = "~/Dropbox (MIT)/data/MC/dnp/pi0DNPInbREC.root"
epg = epgFromROOT(fname, rec=True)
dvpi0 = epg.getDVpi0()
dvcs = epg.getDVCS(sub2g=True)
pi0MCdnpInb.update({"fname":fname, "epg": epg, "dvpi0": dvpi0, "dvcs": dvcs, "df_epg": epg.df_epg, "df_epgg": epg.df_epgg})

# %%
#pi0 from Andrey, outb, rec
fname = "~/Dropbox (MIT)/data/MC/dnp/pi0DNPOutbMC.root"
epg = epgFromROOT(fname, mc=True)
dvpi0 = epg.getDVpi0()
dvcs = epg.getDVCS()
pi0MCdnpOutb = {"fname_gen":fname, "epg_gen": epg, "dvpi0_gen": dvpi0, "dvcs_gen":dvcs, "df_epg_gen": epg.df_epg, "df_epgg_gen": epg.df_epgg}

# %%
#pi0 from Andrey, inb, rec
fname = "~/Dropbox (MIT)/data/MC/dnp/pi0DNPOutbREC.root"
epg = epgFromROOT(fname, rec=True)
dvpi0 = epg.getDVpi0()
dvcs = epg.getDVCS(sub2g=True)
pi0MCdnpOutb.update({"fname":fname, "epg": epg, "dvpi0": dvpi0, "dvcs": dvcs, "df_epg": epg.df_epg, "df_epgg": epg.df_epgg})

# %%
#free up memory a little bit!
epg = None
dvpi0 = None
dvcs = None

# %% [markdown]
# ## 2. Sanity checks
# A space for check if the data are loaded as expected.

# %%
print(len(dvcsMCVxyzCorrInb["dvcs_gen"]), len(dvcsMCVxyzCorrInb["df_epg_gen"]))
# Out:
# 2137647 3470347

# %% [markdown]
# So, for even with generated MC events, which only consists of DVCS and BH, the current exclusivity cuts are too tight. It clears about 1/3 of statistics!

# %% [markdown]
# ## 3. Defining miscellaneous things useful
# Something that I don't want to include in main code blocks, but still useful.

# %%
# units for plotting
degree = r"${}^{\circ}$"
GeV = "GeV"
GeV2 = "GeV"+r"${}^{2}$"
GeVc = "GeV/c"
GeVc2 = "(GeV/c)"+r"${}^{2}$"

# %%
# matplotlib setting
import matplotlib
pgf_with_latex = {
		"pgf.texsystem": "pdflatex",
		"text.usetex": True,            # use LaTeX to write all text
		"font.family": "sans-serif",         
		"font.sans-serif": "Helvetica",
		"font.size": 25,				# default font size
		"axes.labelsize": 24,			# x and y label size
		"axes.titlesize": 24,           # subfigure title size, i.e. title size when one figure
		"legend.fontsize": 22,			# legend size
		"xtick.labelsize": 23,			# x axis tick label size
		"ytick.labelsize": 23,			# y axis tick label 
		"figure.titlesize": 25,         # Figure title size, useful when you have multiple plots in one canvas.
		"pgf.preamble": r"\usepackage{xcolor}"     # xcolor for colours
}
matplotlib.rcParams.update(pgf_with_latex)

# %% [markdown]
# ## 4. Setting up very loose exclusivity cuts!

# %% [markdown]
# Some DVCS cuts set up for BSA are too tight! Let's restore some cuts from df_epg in DVCS data set, and look at some statistics. Firstly, we start by looking at exclusivity cuts from non-radiative simulations, without any exclusivity cuts, but with kinematics cuts. Here, I focus on forward detector due to central detector's calibration issues.

# %%
#Take Forward part only
dvcsInbSim = dvcsMCVxyzCorrInb["df_epg"][dvcsMCVxyzCorrInb["df_epg"]["Pstat"]<4000]
dvcsOutbSim = dvcsMCVxyzCorrOutb["df_epg"][dvcsMCVxyzCorrOutb["df_epg"]["Pstat"]<4000]

# %%
#Kinematic cuts that should be applied without regard to excl. cuts.
dvcsSim = dvcsInbSim
cut_xBupper = dvcsSim["xB"] < 1  # xB
cut_xBlower = dvcsSim["xB"] > 0  # xB
cut_Q2 = dvcsSim["Q2"] > 1  # Q2
cut_W = dvcsSim["W"] > 2  # W
cut_Ee = dvcsSim["Ee"] > 2  # Ee
cut_Ge = dvcsSim["Ge"] > 2  # Ge
cut_Pp = mag([dvcsSim["Ppx"], dvcsSim["Ppy"], dvcsSim["Ppz"]]) > 0.12  # Pp
dvcsSim = dvcsSim[cut_xBupper & cut_xBlower & cut_Q2 & cut_W & cut_Ee & cut_Ge & cut_Pp]
dvcsInbSim = dvcsSim

dvcsSim = dvcsOutbSim
cut_xBupper = dvcsSim["xB"] < 1  # xB
cut_xBlower = dvcsSim["xB"] > 0  # xB
cut_Q2 = dvcsSim["Q2"] > 1  # Q2
cut_W = dvcsSim["W"] > 2  # W
cut_Ee = dvcsSim["Ee"] > 2  # Ee
cut_Ge = dvcsSim["Ge"] > 2  # Ge
cut_Pp = mag([dvcsSim["Ppx"], dvcsSim["Ppy"], dvcsSim["Ppz"]]) > 0.12  # Pp
dvcsSim = dvcsSim[cut_xBupper & cut_xBlower & cut_Q2 & cut_W & cut_Ee & cut_Ge & cut_Pp]
dvcsOutbSim = dvcsSim

# %%
varstoplot = ["coneAngle", "reconGam", "coplanarity", "ME_epg", "MM2_epg", "MM2_eg", "MM2_ep", "MPt"]
title = [r"$\theta_{e'\gamma}$", r"$\theta_{\gamma_{det.}\gamma_{rec.}}$", r"$\Delta\phi$" , "ME"+r"${}_{epg}$", "MM"+r"${}^{2}_{epg}$", "MM"+r"${}^{2}_{eg}$", "MM"+r"${}^{2}_{ep}$", "MPt"+r"${}_{epg}$"]
unit = [degree, degree, degree, GeV, GeV2, GeV2, GeV2, GeVc]
binstarts = [0, 0, 0, -2, -0.4, 0.1, -0.4 , 0]
binends = [60, 10, 30, 3, 0.4, 1.7, 0.4, 0.5]
fig, axs = plt.subplots(2, 4, figsize = (15,10))
for yind in range(0, 2):
	for xind in range(0,4):
		ind = 4*yind + xind
		start = binstarts[ind]
		end = binends[ind]
		bins = np.linspace(start, end, 51)
		axs[yind, xind].hist(dvcsInbSim[varstoplot[ind]], bins = bins, density = True, histtype='stepfilled', facecolor='none', edgecolor='r')
		axs[yind, xind].hist(dvcsOutbSim[varstoplot[ind]], bins = bins, density = True, histtype='stepfilled', facecolor='none', edgecolor='b')
		axs[yind, xind].set_title(title[ind])
		axs[yind, xind].set_xlabel(title[ind]+" [" + unit[ind] +"]")
		axs[yind, xind].set_xlim([start, end])
plt.tight_layout()
plt.show()
# plt.savefig("simComparison_1.pdf")
plt.clf()

# %% [markdown]
# Now the exclusivity cuts are defined in the way pi0 contamination is reasonably minimized but still a plenty of dvcs events are guaranteed. To check this, looking at pi0 simulation should be the option. Here, I use dvpi0p cuts developed by Andrey and Bobby so that we don't want random photons from radiation, or misidentifiacation of pi0's.
#
# Firstly get some DVCS candidates from pi0 simulation

# %%
#Take Forward part only
dvcsContaminationInbSim = pi0MCdnpInb["df_epg"][pi0MCdnpInb["df_epg"]["Pstat"]<4000]
dvcsContaminationOutbSim = pi0MCdnpOutb["df_epg"][pi0MCdnpOutb["df_epg"]["Pstat"]<4000]

# %%
#Kinematic cuts that should be applied without regard to excl. cuts.
dvcsSim = dvcsContaminationInbSim
cut_xBupper = dvcsSim["xB"] < 1  # xB
cut_xBlower = dvcsSim["xB"] > 0  # xB
cut_Q2 = dvcsSim["Q2"] > 1  # Q2
cut_W = dvcsSim["W"] > 2  # W
cut_Ee = dvcsSim["Ee"] > 2  # Ee
cut_Ge = dvcsSim["Ge"] > 2  # Ge
cut_Pp = mag([dvcsSim["Ppx"], dvcsSim["Ppy"], dvcsSim["Ppz"]]) > 0.12  # Pp
dvcsSim = dvcsSim[cut_xBupper & cut_xBlower & cut_Q2 & cut_W & cut_Ee & cut_Ge & cut_Pp]
dvcsContaminationInbSim = dvcsSim

dvcsSim = dvcsContaminationOutbSim
cut_xBupper = dvcsSim["xB"] < 1  # xB
cut_xBlower = dvcsSim["xB"] > 0  # xB
cut_Q2 = dvcsSim["Q2"] > 1  # Q2
cut_W = dvcsSim["W"] > 2  # W
cut_Ee = dvcsSim["Ee"] > 2  # Ee
cut_Ge = dvcsSim["Ge"] > 2  # Ge
cut_Pp = mag([dvcsSim["Ppx"], dvcsSim["Ppy"], dvcsSim["Ppz"]]) > 0.12  # Pp
dvcsSim = dvcsSim[cut_xBupper & cut_xBlower & cut_Q2 & cut_W & cut_Ee & cut_Ge & cut_Pp]
dvcsContaminationOutbSim = dvcsSim

# %% [markdown]
# Now, get the events, which are sorted as pi0 events.

# %%
#Take Forward part only
pi0InbSim = pi0MCdnpInb["dvpi0"][pi0MCdnpInb["dvpi0"]["Pstat"]<4000]
pi0OutbSim = pi0MCdnpInb["dvpi0"][pi0MCdnpInb["dvpi0"]["Pstat"]<4000]

# %% [markdown]
# We reject events that are reconstructed pi0->2\gamma, because we can do this for actual experiment, and we have to.

# %%
pi0to2gammas = dvcsContaminationInbSim["event"].isin(pi0InbSim["event"])
dvcsContaminationInbSim = dvcsContaminationInbSim[~pi0to2gammas]
pi0to2gammas = dvcsContaminationOutbSim["event"].isin(pi0OutbSim["event"])
dvcsContaminationOutbSim = dvcsContaminationOutbSim[~pi0to2gammas]

# %%
varstoplot = ["coneAngle", "reconGam", "coplanarity", "ME_epg", "MM2_epg", "MM2_eg", "MM2_ep", "MPt"]
title = [r"$\theta_{e'\gamma}$", r"$\theta_{\gamma_{det.}\gamma_{rec.}}$", r"$\Delta\phi$" , "ME"+r"${}_{epg}$", "MM"+r"${}^{2}_{epg}$", "MM"+r"${}^{2}_{eg}$", "MM"+r"${}^{2}_{ep}$", "MPt"+r"${}_{epg}$"]
unit = [degree, degree, degree, GeV, GeV2, GeV2, GeV2, GeVc]
binstarts = [0, 0, 0, -2, -0.4, 0.1, -0.4 , 0]
binends = [60, 10, 30, 3, 0.4, 1.7, 0.4, 0.5]
fig, axs = plt.subplots(2, 4, figsize = (15,10))
for yind in range(0, 2):
	for xind in range(0,4):
		ind = 4*yind + xind
		start = binstarts[ind]
		end = binends[ind]
		bins = 201
		axs[yind, xind].hist(dvcsContaminationInbSim[varstoplot[ind]], bins = bins, density = True, histtype='stepfilled', facecolor='none', edgecolor='r')
		axs[yind, xind].hist(dvcsContaminationOutbSim[varstoplot[ind]], bins = bins, density = True, histtype='stepfilled', facecolor='none', edgecolor='b')
		axs[yind, xind].set_title(title[ind])
		axs[yind, xind].set_xlabel(title[ind]+" [" + unit[ind] +"]")
		axs[yind, xind].set_xlim([start, end])
plt.tight_layout()
plt.show()
# plt.savefig("simComparison_1.pdf")
plt.clf()

# %% [markdown]
# It is a bit hard to directly compare these! Let's draw inbending where color codes are black for DVCS simulation and green for Pi0 Simulation.

# %%
#inbending!
varstoplot = ["coneAngle", "reconGam", "coplanarity", "ME_epg", "MM2_epg", "MM2_eg", "MM2_ep", "MPt"]
title = [r"$\theta_{e'\gamma}$", r"$\theta_{\gamma_{det.}\gamma_{rec.}}$", r"$\Delta\phi$" , "ME"+r"${}_{epg}$", "MM"+r"${}^{2}_{epg}$", "MM"+r"${}^{2}_{eg}$", "MM"+r"${}^{2}_{ep}$", "MPt"+r"${}_{epg}$"]
unit = [degree, degree, degree, GeV, GeV2, GeV2, GeV2, GeVc]
binstarts = [0, 0, 0, -2, -0.4, 0.1, -0.4 , 0]
binends = [60, 10, 30, 3, 0.4, 1.7, 0.4, 0.5]
fig, axs = plt.subplots(2, 4, figsize = (15,10))
for yind in range(0, 2):
	for xind in range(0,4):
		ind = 4*yind + xind
		start = binstarts[ind]
		end = binends[ind]
		bins = 201
		axs[yind, xind].hist(dvcsInbSim[varstoplot[ind]], bins = bins, density = True, histtype='stepfilled', facecolor='none', edgecolor='k')
		axs[yind, xind].hist(dvcsContaminationInbSim[varstoplot[ind]], bins = bins, density = True, histtype='stepfilled', facecolor='none', edgecolor='g')
		axs[yind, xind].set_title(title[ind])
		axs[yind, xind].set_xlabel(title[ind]+" [" + unit[ind] +"]")
		axs[yind, xind].set_xlim([start, end])
plt.tight_layout()
plt.show()
# plt.savefig("simComparison_1.pdf")
plt.clf()

# %%
#outbending!
varstoplot = ["coneAngle", "reconGam", "coplanarity", "ME_epg", "MM2_epg", "MM2_eg", "MM2_ep", "MPt"]
title = [r"$\theta_{e'\gamma}$", r"$\theta_{\gamma_{det.}\gamma_{rec.}}$", r"$\Delta\phi$" , "ME"+r"${}_{epg}$", "MM"+r"${}^{2}_{epg}$", "MM"+r"${}^{2}_{eg}$", "MM"+r"${}^{2}_{ep}$", "MPt"+r"${}_{epg}$"]
unit = [degree, degree, degree, GeV, GeV2, GeV2, GeV2, GeVc]
binstarts = [0, 0, 0, -2, -0.4, 0.1, -0.4 , 0]
binends = [60, 10, 30, 3, 0.4, 1.7, 0.4, 0.5]
fig, axs = plt.subplots(2, 4, figsize = (15,10))
for yind in range(0, 2):
	for xind in range(0,4):
		ind = 4*yind + xind
		start = binstarts[ind]
		end = binends[ind]
		bins = 201
		axs[yind, xind].hist(dvcsOutbSim[varstoplot[ind]], bins = bins, density = True, histtype='stepfilled', facecolor='none', edgecolor='k')
		axs[yind, xind].hist(dvcsContaminationOutbSim[varstoplot[ind]], bins = bins, density = True, histtype='stepfilled', facecolor='none', edgecolor='g')
		axs[yind, xind].set_title(title[ind])
		axs[yind, xind].set_xlabel(title[ind]+" [" + unit[ind] +"]")
		axs[yind, xind].set_xlim([start, end])
plt.tight_layout()
plt.show()
# plt.savefig("simComparison_1.pdf")
plt.clf()

# %% [markdown]
# The two sources show differences in (1) missing energy, (2) missing mass of egX, (3) angle between reconstructed photons and detected photons, and  (4) missing transverse momentum. Here, I'm setting cuts that are very loose and contingent.

# %%
#outbending!
varstoplot = ["coneAngle", "reconGam", "coplanarity", "ME_epg", "MM2_epg", "MM2_eg", "MM2_ep", "MPt"]
title = [r"$\theta_{e'\gamma}$", r"$\theta_{\gamma_{det.}\gamma_{rec.}}$", r"$\Delta\phi$" , "ME"+r"${}_{epg}$", "MM"+r"${}^{2}_{epg}$", "MM"+r"${}^{2}_{eg}$", "MM"+r"${}^{2}_{ep}$", "MPt"+r"${}_{epg}$"]
unit = [degree, degree, degree, GeV, GeV2, GeV2, GeV2, GeVc]
binstarts = [0, 0, 0, -0.5, -0.1, 0, -0.6 , 0]
binends = [10, 2.5, 15, 1.2, 0.1, 2, 0.6, 0.25]
fig, axs = plt.subplots(2, 4, figsize = (15,10))
for yind in range(0, 2):
	for xind in range(0,4):
		ind = 4*yind + xind
		start = binstarts[ind]
		end = binends[ind]
		bins = 201
		axs[yind, xind].hist(dvcsInbSim[varstoplot[ind]], bins = bins, density = True, histtype='stepfilled', facecolor='none', edgecolor='k')
		axs[yind, xind].hist(dvcsContaminationInbSim[varstoplot[ind]], bins = bins, density = True, histtype='stepfilled', facecolor='none', edgecolor='g')
		axs[yind, xind].set_title(title[ind])
		axs[yind, xind].set_xlabel(title[ind]+" [" + unit[ind] +"]")
		axs[yind, xind].set_xlim([start, end])
plt.tight_layout()
plt.show()
# plt.savefig("simComparison_1.pdf")
plt.clf()

# %% [markdown]
# Now, load the dvcs candidates from data.

# %%
#Take Forward part only
dvcsInbExp = dvcsExpInb["df_epg"][dvcsExpInb["df_epg"]["Pstat"]<4000]
dvcsOutbExp = dvcsExpOutb["df_epg"][dvcsExpOutb["df_epg"]["Pstat"]<4000]

# %%
#Kinematic cuts that should be applied without regard to excl. cuts.
dvcsExp = dvcsInbExp
cut_xBupper = dvcsExp["xB"] < 1  # xB
cut_xBlower = dvcsExp["xB"] > 0  # xB
cut_Q2 = dvcsExp["Q2"] > 1  # Q2
cut_W = dvcsExp["W"] > 2  # W
cut_Ee = dvcsExp["Ee"] > 2  # Ee
cut_Ge = dvcsExp["Ge"] > 2  # Ge
cut_Pp = mag([dvcsExp["Ppx"], dvcsExp["Ppy"], dvcsExp["Ppz"]]) > 0.12  # Pp
dvcsExp = dvcsExp[cut_xBupper & cut_xBlower & cut_Q2 & cut_W & cut_Ee & cut_Ge & cut_Pp]
dvcsInbExp = dvcsExp

dvcsExp = dvcsOutbExp
cut_xBupper = dvcsExp["xB"] < 1  # xB
cut_xBlower = dvcsExp["xB"] > 0  # xB
cut_Q2 = dvcsExp["Q2"] > 1  # Q2
cut_W = dvcsExp["W"] > 2  # W
cut_Ee = dvcsExp["Ee"] > 2  # Ee
cut_Ge = dvcsExp["Ge"] > 2  # Ge
cut_Pp = mag([dvcsExp["Ppx"], dvcsExp["Ppy"], dvcsExp["Ppz"]]) > 0.12  # Pp
dvcsExp = dvcsExp[cut_xBupper & cut_xBlower & cut_Q2 & cut_W & cut_Ee & cut_Ge & cut_Pp]
dvcsOutbExp = dvcsExp

# %%
#Take dvpi0 events
pi0InbExp = pi0ExpInb["dvpi0"][pi0ExpInb["dvpi0"]["Pstat"]<4000]
pi0OutbExp = pi0ExpOutb["dvpi0"][pi0ExpOutb["dvpi0"]["Pstat"]<4000]

# %%
#pi0->2gamma subtraction
pi0to2gammas = dvcsInbExp["event"].isin(pi0InbExp["event"])
dvcsInbExp = dvcsInbExp[~pi0to2gammas]
pi0to2gammas = dvcsOutbExp["event"].isin(pi0OutbExp["event"])
dvcsOutbExp = dvcsOutbExp[~pi0to2gammas]

# %%
#very loose exclusivity cuts
cut_mmepg = np.abs(dvcsInbExp["MM2_epg"]) < 0.1  # mmepg
cut_mmep = np.abs(dvcsInbExp["MM2_ep"]) < 0.2  # mmepg
cut_mmegupper = dvcsInbExp["MM2_eg"] < 4  # mmeg
cut_mmeglower = dvcsInbExp["MM2_eg"] > 0  # mmeg
cut_meepgupper = dvcsInbExp["ME_epg"] < 1.2  # meepg
cut_meepglower = dvcsInbExp["ME_epg"] > -0.5  # meepg
cut_mpt = dvcsInbExp["MPt"] < 0.25  # mpt
cut_cone = dvcsInbExp["coneAngle"] > 5  # coneangle
cut_recon = dvcsInbExp["reconGam"] < 2.5  # recon gam angle
cut_coplanarity = dvcsInbExp["coplanarity"] < 15  # recon gam angle
cut_sector = dvcsInbExp["Esector"]!=dvcsInbExp["Gsector"]
dvcsInbExp = dvcsInbExp[cut_mmepg & cut_mmegupper & cut_mmeglower & cut_meepgupper & cut_meepglower & cut_mpt & cut_cone & cut_recon & cut_sector]


cut_mmepg = np.abs(dvcsOutbExp["MM2_epg"]) < 0.1  # mmepg
cut_mmep = np.abs(dvcsOutbExp["MM2_ep"]) < 0.2  # mmepg
cut_mmegupper = dvcsOutbExp["MM2_eg"] < 4  # mmeg
cut_mmeglower = dvcsOutbExp["MM2_eg"] > 0  # mmeg
cut_meepgupper = dvcsOutbExp["ME_epg"] < 1.2  # meepg
cut_meepglower = dvcsOutbExp["ME_epg"] > -0.5  # meepg
cut_mpt = dvcsOutbExp["MPt"] < 0.25  # mpt
cut_cone = dvcsOutbExp["coneAngle"] > 5  # coneangle
cut_recon = dvcsOutbExp["reconGam"] < 2.5  # recon gam angle
cut_coplanarity = dvcsOutbExp["coplanarity"] < 15  # recon gam angle
cut_sector = dvcsOutbExp["Esector"]!=dvcsOutbExp["Gsector"]
dvcsOutbExp = dvcsOutbExp[cut_mmepg & cut_mmegupper & cut_mmeglower & cut_meepgupper & cut_meepglower & cut_mpt & cut_cone & cut_recon & cut_sector]

# %%
print(len(dvcsInbExp), len(dvcsOutbExp))
# Out:
# 180918 207465

# %% [markdown]
# ## 5. Rudimentary pi0 subtraction (not bin by bin)

# %% [markdown]
# Now I restored some DVCS events, potentially contaminated by pi0 events. It's doable to estimate pi0 contamination in this cuts using both data and simulation.
#
# pi0->1 gamma (data) = pi0->1 gamma (MC, rec) / pi0->2gamma(MC, rec) * pi0->2gamma(data)!
